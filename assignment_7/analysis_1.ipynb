# %% [markdown]
# # Análise das características, fase 1
#
# A base de dados extraída é composta por **21** características e **924** entradas.
#
# **Não** existem duplicatas, **nem** valores faltantes.

# %%
# %%html
# <link rel="stylesheet" href="./style.css">
# Out:
# <link rel="stylesheet" href="./style.css">

# %%
from IPython.display import HTML, display

from data import df
from plotting import (
    display_feature_description,
    plot_bar_graph_of_frequency,
    plot_bar_graph_of_frequency_by_age_group,
    plot_histogram,
    plot_histogram_by_age_group,
)

# %%
# Display statistics
display(HTML("<strong>Data types:</strong>"))
display(df.dtypes)

display(HTML("<strong>Missing values:</strong>"))
display(df.isna().sum())

display(HTML(f"<strong>Duplicated rows:</strong> {df.duplicated().sum()}"))
# Out:
# <strong>Data types:</strong>
# id                    int64
# age                   int64
# sex                category
# mouth_condition    category
# amount_of_im          int64
# amount_of_cp          int64
# amount_of_p           int64
# amount_of_h           int64
# amount_of_rr          int64
# amount_of_m3i         int64
# amount_of_m3f         int64
# amount_of_te          int64
# amount_of_ri          int64
# amount_of_dc          int64
# amount_of_di          int64
# amount_of_c           int64
# amount_of_r           int64
# amount_of_i           int64
# amount_of_tem         int64
# amount_of_rim         int64
# amount_of_cpum        int64
# age_group          category
# dtype: object
# <strong>Missing values:</strong>
# id                 0
# age                0
# sex                0
# mouth_condition    0
# amount_of_im       0
# amount_of_cp       0
# amount_of_p        0
# amount_of_h        0
# amount_of_rr       0
# amount_of_m3i      0
# amount_of_m3f      0
# ...

# %%
series = df.age
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
)
plot_histogram(
    series=series,
)


series = df.age_group
display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)


series = df.sex
display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.mouth_condition
display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_im
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_cp
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)


series = df.amount_of_p
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_h
bin_width = 5
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_histogram(
    series=series,
    bin_width=bin_width,
)
plot_histogram_by_age_group(
    series=series,
    bin_width=bin_width,
)


series = df.amount_of_rr
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_m3i
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_m3f
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_te
bin_width = 1
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_histogram(
    series=series,
    bin_width=bin_width,
)
plot_histogram_by_age_group(
    series=series,
    bin_width=bin_width,
)


series = df.amount_of_ri
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_dc
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_di
bin_width = 1
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_histogram(
    series=series,
    bin_width=bin_width,
)
plot_histogram_by_age_group(
    series=series,
    bin_width=bin_width,
)


series = df.amount_of_c
bin_width = 1
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_histogram(
    series=series,
    bin_width=bin_width,
)
plot_histogram_by_age_group(
    series=series,
    bin_width=bin_width,
)


series = df.amount_of_r
bin_width = 2
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_histogram(
    series=series,
    bin_width=bin_width,
)
plot_histogram_by_age_group(
    series=series,
    bin_width=bin_width,
)


series = df.amount_of_i
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_tem
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_rim
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_bar_graph_of_frequency(
    series=series,
)
plot_bar_graph_of_frequency_by_age_group(
    series=series,
)


series = df.amount_of_cpum
bin_width = 1
display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_group=df.age_group,
)
plot_histogram(
    series=series,
    bin_width=bin_width,
)
plot_histogram_by_age_group(
    series=series,
    bin_width=bin_width,
)
# Out:
#     <h2>Age</h2>
#     <table>
#         <caption>Age</caption>
#         <tbody>
#             <tr>
#                 <th>ID</th>
#                 <td colspan="2">age</td>
#             </tr>
#             <tr>
#                 <th>Tipo</th>
#                 <td colspan="2">Inteiro</td>
#             </tr>
#
#             <tr>
#                 <th>Intervalo</th>
#                 <td colspan="2">
#                     [11, 88]
#                 </td>
#             </tr>
#             <tr>
#                 <th>Média</th>
#                 <td colspan="2">44.44</td>
#             </tr>
#             <tr>
#                 <th>Mediana</th>
#                 <td colspan="2">46.00</td>
#             </tr>
#             <tr>
#                 <th>Desvio padrão</th>
#                 <td colspan="2">17.80</td>
#             </tr>
#             <tr>
#                 <th rowspan="5">Percentil</th>
#                 <th>05%</th>
#                 <td>19.00</td>
#             </tr>
# ...
