# %% [markdown]
# # Análise das características
#
# A base de dados extraída é composta por **21** características e **924** entradas.
#
# **Não** existem duplicatas, **nem** valores faltantes.

# %%
# %%html
# <link rel="stylesheet" href="./style.css">
# Out:
# <link rel="stylesheet" href="./style.css">

# %%
from data import df
from plotting import (
    display_feature_description,
    plot_bar_graph_of_frequency,
    plot_histogram,
)

# %%
series = df.age

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
)
plot_histogram(
    series=series,
)
# Out:
# <table><caption>Age</caption><tbody>
#     <tr><th>ID</th><td colspan="2">age</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[11, 88]</td></tr>
#         <tr><th>Média</th><td colspan="2">44.44</td></tr>
#         <tr><th>Mediana</th><td colspan="2">46.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">17.80</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>19.00</td></tr>
#         <tr><th>25%</th><td>27.00</td></tr>
#         <tr><th>50%</th><td>46.00</td></tr>
#         <tr><th>75%</th><td>58.00</td></tr>
#         <tr><th>95%</th><td>73.00</td></tr></tbody></table>

# %%
series = df.age_range

display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Age range</caption><tbody>
#     <tr><th>ID</th><td colspan="2">age_range</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>10-19</li><li>20-29</li><li>30-39</li><li>40-49</li><li>50-59</li><li>60-69</li><li>70+</li></ul></td></tr></tbody></table>

# %%
series = df.sex

display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Sex</caption><tbody>
#     <tr><th>ID</th><td colspan="2">sex</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>Feminine</li><li>Masculine</li></ul></td></tr></tbody></table>

# %%
series = df.mouth_condition

display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Mouth condition</caption><tbody>
#     <tr><th>ID</th><td colspan="2">mouth_condition</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>Dentate (De)</li><li>Edentulous (Ed)</li><li>Mandible edentulous (Mne)</li><li>Maxilla edentulous (Me)</li></ul></td></tr></tbody></table>

# %%
series = df.amount_of_im

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Am. Implant (Im)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_im</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 7]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.10</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.62</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>0.00</td></tr></tbody></table>

# %%
series = df.amount_of_cp

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
# Out:
# <table><caption>Am. Single prosthetic crown (Cp)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_cp</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 0]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.00</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.00</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>0.00</td></tr></tbody></table>

# %%
series = df.amount_of_p

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Am. Pontic (P)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_p</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 5]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.14</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.62</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>1.00</td></tr></tbody></table>

# %%
series = df.amount_of_h

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_histogram(
    series=series,
)
# Out:
# <table><caption>Am. Healthy (H)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_h</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 32]</td></tr>
#         <tr><th>Média</th><td colspan="2">11.54</td></tr>
#         <tr><th>Mediana</th><td colspan="2">10.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">9.57</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>3.00</td></tr>
#         <tr><th>50%</th><td>10.00</td></tr>
#         <tr><th>75%</th><td>20.00</td></tr>
#         <tr><th>95%</th><td>28.00</td></tr></tbody></table>

# %%
series = df.amount_of_rr

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Am. Residual root (Rr)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_rr</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 7]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.15</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.61</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>1.00</td></tr></tbody></table>

# %%
series = df.amount_of_m3i

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Am. Impacted third molar (M3i)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_m3i</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 4]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.33</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.85</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>2.00</td></tr></tbody></table>

# %%
series = df.amount_of_m3f

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Am. Developing third molar (M3f)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_m3f</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 4]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.21</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.84</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>2.00</td></tr></tbody></table>
