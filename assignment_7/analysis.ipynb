# %% [markdown]
# # Análise das características
#
# A base de dados extraída é composta por **24** características e **924** entradas.
#
# **Não** existem duplicatas, **nem** valores faltantes.

# %%
# %%html
# <link rel="stylesheet" href="./style.css">
# Out:
# <link rel="stylesheet" href="./style.css">

# %%
from data import df
from plotting import (
    display_feature_description,
    plot_bar_graph_of_frequency,
    plot_histogram,
)
# Out:
# 'Data types:'
# id                   int64
# age                  int64
# sex               category
# amount_of_ed         int64
# amount_of_m3f        int64
# amount_of_h          int64
# amount_of_de         int64
# amount_of_r          int64
# amount_of_m3i        int64
# amount_of_cpum       int64
# amount_of_te         int64
# amount_of_di         int64
# amount_of_c          int64
# amount_of_p          int64
# amount_of_me         int64
# amount_of_im         int64
# amount_of_rr         int64
# amount_of_dc         int64
# amount_of_i          int64
# amount_of_mne        int64
# amount_of_ri         int64
# amount_of_rim        int64
# amount_of_tem        int64
# amount_of_cp         int64
# age_range         category
# dtype: object
# 'Missing values:'
# id                0
# age               0
# sex               0
# amount_of_ed      0
# amount_of_m3f     0
# amount_of_h       0
# amount_of_de      0
# amount_of_r       0
# amount_of_m3i     0
# amount_of_cpum    0
# amount_of_te      0
# amount_of_di      0
# amount_of_c       0
# amount_of_p       0
# amount_of_me      0
# amount_of_im      0
# amount_of_rr      0
# amount_of_dc      0
# amount_of_i       0
# amount_of_mne     0
# amount_of_ri      0
# amount_of_rim     0
# amount_of_tem     0
# amount_of_cp      0
# age_range         0
# dtype: int64
# 'Duplicated rows: 0'

# %%
series = df.sex

display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Sex</caption><tbody>
#     <tr><th>ID</th><td colspan="2">sex</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>F</li><li>M</li></ul></td></tr></tbody></table>

# %%
series = df.age

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
)
plot_histogram(
    series=series,
)
# Out:
# <table><caption>Age</caption><tbody>
#     <tr><th>ID</th><td colspan="2">age</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[11, 88]</td></tr>
#         <tr><th>Média</th><td colspan="2">44.44</td></tr>
#         <tr><th>Mediana</th><td colspan="2">46.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">17.80</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>19.00</td></tr>
#         <tr><th>25%</th><td>27.00</td></tr>
#         <tr><th>50%</th><td>46.00</td></tr>
#         <tr><th>75%</th><td>58.00</td></tr>
#         <tr><th>95%</th><td>73.00</td></tr></tbody></table>

# %%
series = df.age_range

display_feature_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Age range</caption><tbody>
#     <tr><th>ID</th><td colspan="2">age_range</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>10-19</li><li>20-29</li><li>30-39</li><li>40-49</li><li>50-59</li><li>60-69</li><li>70+</li></ul></td></tr></tbody></table>

# %%
series = df.amount_of_c

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_histogram(
    series=series,
    bin_width=1,
)
# Out:
# <table><caption>Am. Caries (C)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_c</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 9]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.43</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.99</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>2.00</td></tr></tbody></table>

# %%
series = df.amount_of_cp

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
# Out:
# <table><caption>Am. Single prosthetic crown (Cp)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_cp</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 0]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.00</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.00</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>0.00</td></tr></tbody></table>

# %%
series = df.amount_of_cpum

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_histogram(
    series=series,
    bin_width=1,
)
# Out:
# <table><caption>Am. Single prosthetic crown (mixed) (CpuM)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_cpum</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 10]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.42</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.18</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>3.00</td></tr></tbody></table>

# %%
series = df.amount_of_dc

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_histogram(
    series=series,
    bin_width=1,
)
# Out:
# <table><caption>Am. Crown destruction (Dc)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_dc</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 10]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.07</td></tr>
#         <tr><th>Mediana</th><td colspan="2">0.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.47</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>0.00</td></tr>
#         <tr><th>50%</th><td>0.00</td></tr>
#         <tr><th>75%</th><td>0.00</td></tr>
#         <tr><th>95%</th><td>0.00</td></tr></tbody></table>

# %%
series = df.amount_of_de

display_feature_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
    age_range=df.age_range,
)
plot_bar_graph_of_frequency(
    series=series,
)
# Out:
# <table><caption>Am. Dentate (De)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">amount_of_de</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[0, 1]</td></tr>
#         <tr><th>Média</th><td colspan="2">0.79</td></tr>
#         <tr><th>Mediana</th><td colspan="2">1.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.41</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>0.00</td></tr>
#         <tr><th>25%</th><td>1.00</td></tr>
#         <tr><th>50%</th><td>1.00</td></tr>
#         <tr><th>75%</th><td>1.00</td></tr>
#         <tr><th>95%</th><td>1.00</td></tr></tbody></table>
