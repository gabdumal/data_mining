# %% [markdown]
# # Análise das características, fase 2
#
# A base de dados extraída é composta por **15** características e **924** entradas.

# %%
# %%html
# <link rel="stylesheet" href="./style.css">
# Out:
# <link rel="stylesheet" href="./style.css">

# %%
from data import df2
from helper_for_analysis import (
    display_condition_counts_among_affected_by_age_group,
    display_condition_counts_by_age_group,
    display_condition_presence_by_age_group,
)
# Out:
# amount_of_im     False     True
# age_group
# 10-19         1.000000  0.000000
# 20-29         0.994949  0.005051
# 30-39         0.982143  0.017857
# 40-49         0.980392  0.019608
# 50-59         0.940594  0.059406
# 60-69         0.904348  0.095652
# 70+           0.953488  0.046512

# %%
condition_columns = [
    column for column in df2.columns if column.startswith("amount_of_")
]

display_condition_presence_by_age_group(
    df2,
    condition_columns,
)

display_condition_counts_by_age_group(
    df2,
    condition_columns,
)

display_condition_counts_among_affected_by_age_group(
    df2,
    condition_columns,
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8fdda">
#   <caption>Presence of dental conditions by age group</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fdda_level0_col0" class="col_heading level0 col0" >General</th>
#       <th id="T_8fdda_level0_col1" class="col_heading level0 col1" >10-19</th>
#       <th id="T_8fdda_level0_col2" class="col_heading level0 col2" >20-29</th>
#       <th id="T_8fdda_level0_col3" class="col_heading level0 col3" >30-39</th>
#       <th id="T_8fdda_level0_col4" class="col_heading level0 col4" >40-49</th>
#       <th id="T_8fdda_level0_col5" class="col_heading level0 col5" >50-59</th>
#       <th id="T_8fdda_level0_col6" class="col_heading level0 col6" >60-69</th>
#       <th id="T_8fdda_level0_col7" class="col_heading level0 col7" >70+</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Feature</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
