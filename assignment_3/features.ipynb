# %% [markdown]
# # Descrição das características

# %%
# %%html
# <link rel="stylesheet" href="./style.css">
# Out:
# <link rel="stylesheet" href="./style.css">

# %%
from typing import Literal

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import HTML, display

from data import dd_df, names_of_columns
from plotting import generate_bar_graph, generate_histogram

# %%
def get_numerical_range(
    series: pd.Series,
):
    min_value, max_value = series.min(), series.max()
    if hasattr(min_value, "strftime") and hasattr(max_value, "strftime"):
        min_text = min_value.strftime("%Y-%m-%d")
        max_text = max_value.strftime("%Y-%m-%d")
    else:
        min_text = str(min_value)
        max_text = str(max_value)
    return f"[{min_text}, {max_text}]"

# %%
def display_column_description(
    series: pd.Series,
    type_name: str,
    feature_type: Literal["categorical", "numerical", "other"] = "other",
):
    descriptive_name = names_of_columns[series.name]
    block_to_display = f"<table><caption>{descriptive_name}</caption><tbody>"

    block_to_display += f"""
    <tr><th>ID</th><td colspan="2">{series.name}</td></tr>
    <tr><th>Tipo</th><td colspan="2">{type_name}</td></tr>"""

    if feature_type == "categorical":
        values = sorted(series.dropna().unique().tolist())
        values_html = (
            "<ul style='list-style-type: none;'>"
            + "".join(f"<li>{v}</li>" for v in values)
            + "</ul>"
        )
        block_to_display += f"<tr><th>Valores</th><td>{values_html}</td></tr>"

    elif feature_type == "numerical":
        block_to_display += f"""<tr><th>Intervalo</th><td colspan="2">{get_numerical_range(series)}</td></tr>"""
        block_to_display += f"""
        <tr><th>Média</th><td colspan="2">{series.mean():.2f}</td></tr>
        <tr><th>Mediana</th><td colspan="2">{series.median():.2f}</td></tr>
        <tr><th>Desvio padrão</th><td colspan="2">{series.std():.2f}</td></tr>
        <tr><th rowspan="5">Percentil</th><th>05%</th><td>{series.quantile(0.05):.2f}</td></tr>
        <tr><th>25%</th><td>{series.quantile(0.25):.2f}</td></tr>
        <tr><th>50%</th><td>{series.quantile(0.5):.2f}</td></tr>
        <tr><th>75%</th><td>{series.quantile(0.75):.2f}</td></tr>
        <tr><th>95%</th><td>{series.quantile(0.95):.2f}</td></tr>"""
        plt.boxplot(series.dropna())
        plt.xlabel("Boxplot")
        plt.ylabel(descriptive_name)

    display(HTML(block_to_display + "</tbody></table>"))
    plt.show()

# %%
series = dd_df.hectares

display_column_description(
    series=series,
    type_name="Inteiro",
    feature_type="numerical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Hectares</caption><tbody>
#     <tr><th>ID</th><td colspan="2">hectares</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Inteiro</td></tr><tr><th>Intervalo</th><td colspan="2">[1, 6]</td></tr>
#         <tr><th>Média</th><td colspan="2">3.70</td></tr>
#         <tr><th>Mediana</th><td colspan="2">4.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.46</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>1.00</td></tr>
#         <tr><th>25%</th><td>3.00</td></tr>
#         <tr><th>50%</th><td>4.00</td></tr>
#         <tr><th>75%</th><td>5.00</td></tr>
#         <tr><th>95%</th><td>6.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.agriblock

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Agriblock</caption><tbody>
#     <tr><th>ID</th><td colspan="2">agriblock</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>Chinnasalem</li><li>Cuddalore</li><li>Kallakurichi</li><li>Kurinjipadi</li><li>Panruti</li><li>Sankarapuram</li></ul></td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.variety

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 3
#       1 series = dd_df.variety
#       2
# ----> 3 display(dd_df[["variety", "trash_per_hectare"]])
#       4
#       5 display_column_description(
#       6     series=series,
#
# File ~/dev/data_mining/assignment_3/.venv/lib64/python3.14/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
series = dd_df.soil_type

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Soil Types</caption><tbody>
#     <tr><th>ID</th><td colspan="2">soil_type</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>alluvial</li><li>clay</li></ul></td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.seed_rate

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Seedrate (in Kg)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">seed_rate</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[25, 150]</td></tr>
#         <tr><th>Média</th><td colspan="2">92.59</td></tr>
#         <tr><th>Mediana</th><td colspan="2">100.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">36.45</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>25.00</td></tr>
#         <tr><th>25%</th><td>75.00</td></tr>
#         <tr><th>50%</th><td>100.00</td></tr>
#         <tr><th>75%</th><td>125.00</td></tr>
#         <tr><th>95%</th><td>150.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.lp_mainfield

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Land Preparation, Main-field (in Tonnes)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">lp_mainfield</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[12.5, 75.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">46.30</td></tr>
#         <tr><th>Mediana</th><td colspan="2">50.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">18.23</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>12.50</td></tr>
#         <tr><th>25%</th><td>37.50</td></tr>
#         <tr><th>50%</th><td>50.00</td></tr>
#         <tr><th>75%</th><td>62.50</td></tr>
#         <tr><th>95%</th><td>75.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.nursery

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Nursery</caption><tbody>
#     <tr><th>ID</th><td colspan="2">nursery</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>dry</li><li>wet</li></ul></td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.nursery_area

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Nursery area (Cents)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">nursery_area</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[20, 120]</td></tr>
#         <tr><th>Média</th><td colspan="2">74.07</td></tr>
#         <tr><th>Mediana</th><td colspan="2">80.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">29.16</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>20.00</td></tr>
#         <tr><th>25%</th><td>60.00</td></tr>
#         <tr><th>50%</th><td>80.00</td></tr>
#         <tr><th>75%</th><td>100.00</td></tr>
#         <tr><th>95%</th><td>120.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.lp_nursery_area

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Land Preparation, Nursery area (in Tonnes)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">lp_nursery_area</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[1, 6]</td></tr>
#         <tr><th>Média</th><td colspan="2">3.70</td></tr>
#         <tr><th>Mediana</th><td colspan="2">4.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.46</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>1.00</td></tr>
#         <tr><th>25%</th><td>3.00</td></tr>
#         <tr><th>50%</th><td>4.00</td></tr>
#         <tr><th>75%</th><td>5.00</td></tr>
#         <tr><th>95%</th><td>6.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.dap_d20

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>DAP, in 20 days</caption><tbody>
#     <tr><th>ID</th><td colspan="2">dap_d20</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[40, 240]</td></tr>
#         <tr><th>Média</th><td colspan="2">148.15</td></tr>
#         <tr><th>Mediana</th><td colspan="2">160.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">58.32</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>40.00</td></tr>
#         <tr><th>25%</th><td>120.00</td></tr>
#         <tr><th>50%</th><td>160.00</td></tr>
#         <tr><th>75%</th><td>200.00</td></tr>
#         <tr><th>95%</th><td>240.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.weed_d28_thiobencarb

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Weed, in 28 days, thiobencarb</caption><tbody>
#     <tr><th>ID</th><td colspan="2">weed_d28_thiobencarb</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[2, 12]</td></tr>
#         <tr><th>Média</th><td colspan="2">7.41</td></tr>
#         <tr><th>Mediana</th><td colspan="2">8.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">2.92</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>2.00</td></tr>
#         <tr><th>25%</th><td>6.00</td></tr>
#         <tr><th>50%</th><td>8.00</td></tr>
#         <tr><th>75%</th><td>10.00</td></tr>
#         <tr><th>95%</th><td>12.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.urea_d40

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Urea, in 40 days</caption><tbody>
#     <tr><th>ID</th><td colspan="2">urea_d40</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[27.13, 162.78]</td></tr>
#         <tr><th>Média</th><td colspan="2">100.48</td></tr>
#         <tr><th>Mediana</th><td colspan="2">108.52</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">39.56</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>27.13</td></tr>
#         <tr><th>25%</th><td>81.39</td></tr>
#         <tr><th>50%</th><td>108.52</td></tr>
#         <tr><th>75%</th><td>135.65</td></tr>
#         <tr><th>95%</th><td>162.78</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.potash_d50

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Potassh, in 50 days</caption><tbody>
#     <tr><th>ID</th><td colspan="2">potash_d50</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[10.38, 62.28]</td></tr>
#         <tr><th>Média</th><td colspan="2">38.44</td></tr>
#         <tr><th>Mediana</th><td colspan="2">41.52</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">15.13</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>10.38</td></tr>
#         <tr><th>25%</th><td>31.14</td></tr>
#         <tr><th>50%</th><td>41.52</td></tr>
#         <tr><th>75%</th><td>51.90</td></tr>
#         <tr><th>95%</th><td>62.28</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.micronutrients_d70

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Micronutrients, in 70 days</caption><tbody>
#     <tr><th>ID</th><td colspan="2">micronutrients_d70</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[15, 90]</td></tr>
#         <tr><th>Média</th><td colspan="2">55.55</td></tr>
#         <tr><th>Mediana</th><td colspan="2">60.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">21.87</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>15.00</td></tr>
#         <tr><th>25%</th><td>45.00</td></tr>
#         <tr><th>50%</th><td>60.00</td></tr>
#         <tr><th>75%</th><td>75.00</td></tr>
#         <tr><th>95%</th><td>90.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.pesticide_d60

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series, bins=6)
display(HTML("<hr/>"))
# Out:
# <table><caption>Pesticide, 60 Day (in ml)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">pesticide_d60</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[600, 3600]</td></tr>
#         <tr><th>Média</th><td colspan="2">2222.19</td></tr>
#         <tr><th>Mediana</th><td colspan="2">2400.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">874.81</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>600.00</td></tr>
#         <tr><th>25%</th><td>1800.00</td></tr>
#         <tr><th>50%</th><td>2400.00</td></tr>
#         <tr><th>75%</th><td>3000.00</td></tr>
#         <tr><th>95%</th><td>3600.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.rainfall_d1_d30

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Rainfall in days 01 to 30 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">rainfall_d1_d30</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[18.1, 19.6]</td></tr>
#         <tr><th>Média</th><td colspan="2">18.72</td></tr>
#         <tr><th>Mediana</th><td colspan="2">18.50</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.64</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>18.10</td></tr>
#         <tr><th>25%</th><td>18.10</td></tr>
#         <tr><th>50%</th><td>18.50</td></tr>
#         <tr><th>75%</th><td>19.60</td></tr>
#         <tr><th>95%</th><td>19.60</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.irrigation_d1_d30

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Irrigation in days 01 to 30 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">irrigation_d1_d30</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[20.4, 21.9]</td></tr>
#         <tr><th>Média</th><td colspan="2">21.28</td></tr>
#         <tr><th>Mediana</th><td colspan="2">21.50</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.64</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>20.40</td></tr>
#         <tr><th>25%</th><td>20.40</td></tr>
#         <tr><th>50%</th><td>21.50</td></tr>
#         <tr><th>75%</th><td>21.90</td></tr>
#         <tr><th>95%</th><td>21.90</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.rainfall_d30_d50

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Rainfall in days 30 to 50 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">rainfall_d30_d50</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[185.2, 187.2]</td></tr>
#         <tr><th>Média</th><td colspan="2">186.01</td></tr>
#         <tr><th>Mediana</th><td colspan="2">185.60</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.85</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>185.20</td></tr>
#         <tr><th>25%</th><td>185.20</td></tr>
#         <tr><th>50%</th><td>185.60</td></tr>
#         <tr><th>75%</th><td>187.20</td></tr>
#         <tr><th>95%</th><td>187.20</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.irrigation_d30_d50

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Irrigation in days 30 to 50 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">irrigation_d30_d50</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[270.8, 272.8]</td></tr>
#         <tr><th>Média</th><td colspan="2">271.99</td></tr>
#         <tr><th>Mediana</th><td colspan="2">272.40</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.85</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>270.80</td></tr>
#         <tr><th>25%</th><td>270.80</td></tr>
#         <tr><th>50%</th><td>272.40</td></tr>
#         <tr><th>75%</th><td>272.80</td></tr>
#         <tr><th>95%</th><td>272.80</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.rainfall_d51_d70

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Rainfall in days 51 to 70 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">rainfall_d51_d70</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[165.3, 167.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">166.16</td></tr>
#         <tr><th>Mediana</th><td colspan="2">166.10</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.68</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>165.30</td></tr>
#         <tr><th>25%</th><td>165.30</td></tr>
#         <tr><th>50%</th><td>166.10</td></tr>
#         <tr><th>75%</th><td>167.00</td></tr>
#         <tr><th>95%</th><td>167.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.irrigation_d51_d70

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Irrigation in days 51 to 70 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">irrigation_d51_d70</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[250.0, 251.7]</td></tr>
#         <tr><th>Média</th><td colspan="2">250.84</td></tr>
#         <tr><th>Mediana</th><td colspan="2">250.90</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.68</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>250.00</td></tr>
#         <tr><th>25%</th><td>250.00</td></tr>
#         <tr><th>50%</th><td>250.90</td></tr>
#         <tr><th>75%</th><td>251.70</td></tr>
#         <tr><th>95%</th><td>251.70</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.rainfall_d71_d105

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Rainfall in days 71 to 105 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">rainfall_d71_d105</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[60.0, 61.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">60.40</td></tr>
#         <tr><th>Mediana</th><td colspan="2">60.20</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.43</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>60.00</td></tr>
#         <tr><th>25%</th><td>60.00</td></tr>
#         <tr><th>50%</th><td>60.20</td></tr>
#         <tr><th>75%</th><td>61.00</td></tr>
#         <tr><th>95%</th><td>61.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.irrigation_d71_d105

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Irrigation in days 71 to 105 (in mm)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">irrigation_d71_d105</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[64.0, 65.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">64.60</td></tr>
#         <tr><th>Mediana</th><td colspan="2">64.80</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.43</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>64.00</td></tr>
#         <tr><th>25%</th><td>64.00</td></tr>
#         <tr><th>50%</th><td>64.80</td></tr>
#         <tr><th>75%</th><td>65.00</td></tr>
#         <tr><th>95%</th><td>65.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.min_temp_d1_d30

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Minimum temperature in days 01 to 30 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">min_temp_d1_d30</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[18.0, 20.5]</td></tr>
#         <tr><th>Média</th><td colspan="2">19.32</td></tr>
#         <tr><th>Mediana</th><td colspan="2">19.50</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.87</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>18.00</td></tr>
#         <tr><th>25%</th><td>18.50</td></tr>
#         <tr><th>50%</th><td>19.50</td></tr>
#         <tr><th>75%</th><td>20.00</td></tr>
#         <tr><th>95%</th><td>20.50</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.max_temp_d1_d30

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Maximum temperature in days 01 to 30 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">max_temp_d1_d30</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[31, 35]</td></tr>
#         <tr><th>Média</th><td colspan="2">33.11</td></tr>
#         <tr><th>Mediana</th><td colspan="2">33.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.32</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>31.00</td></tr>
#         <tr><th>25%</th><td>32.00</td></tr>
#         <tr><th>50%</th><td>33.00</td></tr>
#         <tr><th>75%</th><td>34.00</td></tr>
#         <tr><th>95%</th><td>35.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.min_temp_d31_d60

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Minimum temperature in days 31 to 60 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">min_temp_d31_d60</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[15.5, 18.5]</td></tr>
#         <tr><th>Média</th><td colspan="2">17.13</td></tr>
#         <tr><th>Mediana</th><td colspan="2">17.50</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.04</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>15.50</td></tr>
#         <tr><th>25%</th><td>16.00</td></tr>
#         <tr><th>50%</th><td>17.50</td></tr>
#         <tr><th>75%</th><td>18.00</td></tr>
#         <tr><th>95%</th><td>18.50</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.max_temp_d31_d60

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Maximum temperature in days 31 to 60 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">max_temp_d31_d60</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[28, 35]</td></tr>
#         <tr><th>Média</th><td colspan="2">31.35</td></tr>
#         <tr><th>Mediana</th><td colspan="2">30.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">2.53</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>28.00</td></tr>
#         <tr><th>25%</th><td>30.00</td></tr>
#         <tr><th>50%</th><td>30.00</td></tr>
#         <tr><th>75%</th><td>34.00</td></tr>
#         <tr><th>95%</th><td>35.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.min_temp_d61_d90

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Minimum temperature in days 61 to 90 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">min_temp_d61_d90</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[15.0, 18.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">16.67</td></tr>
#         <tr><th>Mediana</th><td colspan="2">17.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.07</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>15.00</td></tr>
#         <tr><th>25%</th><td>15.50</td></tr>
#         <tr><th>50%</th><td>17.00</td></tr>
#         <tr><th>75%</th><td>17.50</td></tr>
#         <tr><th>95%</th><td>18.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.max_temp_d61_d90

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Maximum temperature in days 61 to 90 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">max_temp_d61_d90</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[31.0, 34.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">32.66</td></tr>
#         <tr><th>Mediana</th><td colspan="2">33.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.07</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>31.00</td></tr>
#         <tr><th>25%</th><td>31.50</td></tr>
#         <tr><th>50%</th><td>33.00</td></tr>
#         <tr><th>75%</th><td>33.50</td></tr>
#         <tr><th>95%</th><td>34.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.min_temp_d91_d120

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Minimum temperature in days 91 to 120 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">min_temp_d91_d120</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[15.0, 18.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">16.18</td></tr>
#         <tr><th>Mediana</th><td colspan="2">16.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">0.90</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>15.00</td></tr>
#         <tr><th>25%</th><td>15.50</td></tr>
#         <tr><th>50%</th><td>16.00</td></tr>
#         <tr><th>75%</th><td>16.50</td></tr>
#         <tr><th>95%</th><td>18.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.max_temp_d91_d120

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Maximum temperature in days 91 to 120 (in Celsius)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">max_temp_d91_d120</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[30.5, 35.0]</td></tr>
#         <tr><th>Média</th><td colspan="2">32.69</td></tr>
#         <tr><th>Mediana</th><td colspan="2">33.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.49</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>30.50</td></tr>
#         <tr><th>25%</th><td>31.50</td></tr>
#         <tr><th>50%</th><td>33.00</td></tr>
#         <tr><th>75%</th><td>33.00</td></tr>
#         <tr><th>95%</th><td>35.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_speed_d1_d30

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Instantaneous Wind Speed in days 01 to 30 (in Knots)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_speed_d1_d30</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[4, 10]</td></tr>
#         <tr><th>Média</th><td colspan="2">7.22</td></tr>
#         <tr><th>Mediana</th><td colspan="2">8.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">2.55</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>4.00</td></tr>
#         <tr><th>25%</th><td>4.00</td></tr>
#         <tr><th>50%</th><td>8.00</td></tr>
#         <tr><th>75%</th><td>10.00</td></tr>
#         <tr><th>95%</th><td>10.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_speed_d31_d60

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Instantaneous Wind Speed in days 31 to 60 (in Knots)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_speed_d31_d60</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[4, 12]</td></tr>
#         <tr><th>Média</th><td colspan="2">8.48</td></tr>
#         <tr><th>Mediana</th><td colspan="2">10.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">3.19</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>4.00</td></tr>
#         <tr><th>25%</th><td>6.00</td></tr>
#         <tr><th>50%</th><td>10.00</td></tr>
#         <tr><th>75%</th><td>12.00</td></tr>
#         <tr><th>95%</th><td>12.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_speed_d61_d90

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Instantaneous Wind Speed in days 61 to 90 (in Knots)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_speed_d61_d90</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[4, 10]</td></tr>
#         <tr><th>Média</th><td colspan="2">8.16</td></tr>
#         <tr><th>Mediana</th><td colspan="2">8.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">1.98</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>4.00</td></tr>
#         <tr><th>25%</th><td>8.00</td></tr>
#         <tr><th>50%</th><td>8.00</td></tr>
#         <tr><th>75%</th><td>10.00</td></tr>
#         <tr><th>95%</th><td>10.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_speed_d91_d120

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Instantaneous Wind Speed in days 91 to 120 (in Knots)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_speed_d91_d120</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[6, 12]</td></tr>
#         <tr><th>Média</th><td colspan="2">9.43</td></tr>
#         <tr><th>Mediana</th><td colspan="2">10.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">2.51</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>6.00</td></tr>
#         <tr><th>25%</th><td>6.00</td></tr>
#         <tr><th>50%</th><td>10.00</td></tr>
#         <tr><th>75%</th><td>12.00</td></tr>
#         <tr><th>95%</th><td>12.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_direction_d1_d30

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Wind Direction in days 01 to 30</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_direction_d1_d30</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>E</li><li>ENE</li><li>NW</li><li>SSE</li><li>SW</li><li>W</li></ul></td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_direction_d31_d60

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Wind Direction in days 31 to 60</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_direction_d31_d60</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>ENE</li><li>NE</li><li>S</li><li>W</li><li>WNW</li></ul></td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_direction_d61_d90

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Wind Direction in days 61 to 90</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_direction_d61_d90</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>NE</li><li>NNE</li><li>NNW</li><li>SE</li><li>SW</li></ul></td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.wind_direction_d91_d120

display_column_description(
    series=series,
    type_name="Categórico",
    feature_type="categorical",
)
generate_bar_graph(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Wind Direction in days 91 to 120</caption><tbody>
#     <tr><th>ID</th><td colspan="2">wind_direction_d91_d120</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Categórico</td></tr><tr><th>Valores</th><td><ul style='list-style-type: none;'><li>NNW</li><li>NW</li><li>S</li><li>SSE</li><li>W</li><li>WSW</li></ul></td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.relative_humidity_d1_d30

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Relative Humidity in days 01 to 30 (%)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">relative_humidity_d1_d30</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[64.6, 88.5]</td></tr>
#         <tr><th>Média</th><td colspan="2">76.36</td></tr>
#         <tr><th>Mediana</th><td colspan="2">72.70</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">8.00</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>64.60</td></tr>
#         <tr><th>25%</th><td>72.00</td></tr>
#         <tr><th>50%</th><td>72.70</td></tr>
#         <tr><th>75%</th><td>85.00</td></tr>
#         <tr><th>95%</th><td>88.50</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.relative_humidity_d31_d60

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Relative Humidity in days 31 to 60 (%)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">relative_humidity_d31_d60</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[78, 96]</td></tr>
#         <tr><th>Média</th><td colspan="2">87.58</td></tr>
#         <tr><th>Mediana</th><td colspan="2">91.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">6.79</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>78.00</td></tr>
#         <tr><th>25%</th><td>80.00</td></tr>
#         <tr><th>50%</th><td>91.00</td></tr>
#         <tr><th>75%</th><td>95.00</td></tr>
#         <tr><th>95%</th><td>96.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.relative_humidity_d61_d90

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Relative Humidity in days 61 to 90 (%)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">relative_humidity_d61_d90</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[81, 92]</td></tr>
#         <tr><th>Média</th><td colspan="2">85.19</td></tr>
#         <tr><th>Mediana</th><td colspan="2">84.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">3.54</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>81.00</td></tr>
#         <tr><th>25%</th><td>83.00</td></tr>
#         <tr><th>50%</th><td>84.00</td></tr>
#         <tr><th>75%</th><td>88.00</td></tr>
#         <tr><th>95%</th><td>92.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.relative_humidity_d91_d120

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Relative Humidity in days 91 to 120 (%)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">relative_humidity_d91_d120</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[79, 88]</td></tr>
#         <tr><th>Média</th><td colspan="2">83.89</td></tr>
#         <tr><th>Mediana</th><td colspan="2">84.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">3.14</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>79.00</td></tr>
#         <tr><th>25%</th><td>81.00</td></tr>
#         <tr><th>50%</th><td>84.00</td></tr>
#         <tr><th>75%</th><td>87.00</td></tr>
#         <tr><th>95%</th><td>88.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.trash

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Trash (in bundles)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">trash</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[80, 600]</td></tr>
#         <tr><th>Média</th><td colspan="2">333.43</td></tr>
#         <tr><th>Mediana</th><td colspan="2">360.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">135.33</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>90.00</td></tr>
#         <tr><th>25%</th><td>240.00</td></tr>
#         <tr><th>50%</th><td>360.00</td></tr>
#         <tr><th>75%</th><td>450.00</td></tr>
#         <tr><th>95%</th><td>540.00</td></tr></tbody></table>
# <hr/>

# %%
series = dd_df.paddy_yield

display_column_description(
    series=series,
    type_name="Real",
    feature_type="numerical",
)
generate_histogram(series=series)
display(HTML("<hr/>"))
# Out:
# <table><caption>Paddy yield (in Kg)</caption><tbody>
#     <tr><th>ID</th><td colspan="2">paddy_yield</td></tr>
#     <tr><th>Tipo</th><td colspan="2">Real</td></tr><tr><th>Intervalo</th><td colspan="2">[5410, 38814]</td></tr>
#         <tr><th>Média</th><td colspan="2">22410.32</td></tr>
#         <tr><th>Mediana</th><td colspan="2">24460.00</td></tr>
#         <tr><th>Desvio padrão</th><td colspan="2">9316.05</td></tr>
#         <tr><th rowspan="5">Percentil</th><th>05%</th><td>5836.00</td></tr>
#         <tr><th>25%</th><td>16252.50</td></tr>
#         <tr><th>50%</th><td>24460.00</td></tr>
#         <tr><th>75%</th><td>30965.00</td></tr>
#         <tr><th>95%</th><td>35881.20</td></tr></tbody></table>
# <hr/>
